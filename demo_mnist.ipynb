# %% [markdown]
# **Copyright © 2025 Raphael Senn. Licensed under the MIT License.**
#
# **Author:** Raphael Senn (<raphaelsenn@gmx.de>)
#
# # Conditional Generative Adversarial Networks (Mirza and Osindero, 2014)

# %%
import os

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader

from torchvision.transforms import transforms
from torchvision.datasets import MNIST

from src.cgan_fc import (
    Generator,
    Discriminator,
)

from src.objective import (
    GeneratorLoss,
    DiscriminatorLoss
)

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# #### Exploring the training dataset

# %%
transform = transforms.Compose([
    transforms.ToTensor(),                      # pixel transform: img.range[0, 255] -> img.range[0, 1]
    transforms.Lambda(lambda x: x.view(-1))     # shape transfrom: img.shape[1, 28, 28] -> img.shape[1, 784]
])

dataset = MNIST(root='./MNIST/', train=True, download=True, transform=transform)

# %% [markdown]
# #### Visualizing the Training Data

# %%
FIGSIZE = (12, 12)
IMAGE_SHAPE = (28, 28)
N_ROWS, N_COLS = 10, 10

_, ax = plt.subplots(nrows=N_ROWS, ncols=N_COLS, figsize=FIGSIZE)
ax = ax.flatten()

for i in range(N_ROWS * N_COLS):
    img, _ = dataset[i]
    img = img.reshape(IMAGE_SHAPE)
    ax[i].imshow(img, cmap='gray')
    ax[i].set_xticks([]),
    ax[i].set_yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Training Setup

# %%
if torch.cuda.is_available(): 
    torch.cuda.manual_seed(SEED)
    device = torch.device('cuda')
elif torch.backends.mps.is_available(): 
    device = torch.device('mps')
else: 
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: mps

# %%
# Create conditional generator and discriminator
DIM_NOISE = 100
generator = Generator(DIM_NOISE).to(device)
discriminator = Discriminator().to(device)

# Hyperparameters
EPOCHS = 100
BATCH_SIZE = 128
SHUFFLE = True

LR_G = 0.002
LR_D = 0.002

BETAS_G = (0.5, 0.999)
BETAS_D = (0.5, 0.999)

# Create the optimizer and the loss
criterion_g = GeneratorLoss()
optimizer_g = torch.optim.Adam(params=generator.parameters(), lr=LR_G, betas=BETAS_G)

criterion_d = DiscriminatorLoss()
optimizer_d = torch.optim.Adam(params=discriminator.parameters(), lr=LR_D, betas=BETAS_D)

# Load the dataset
dataloader = DataLoader(dataset, BATCH_SIZE, SHUFFLE)

# %%
num_params_g = sum(p.numel() for p in generator.parameters())
num_params_d = sum(p.numel() for p in discriminator.parameters())
print(f'Generator has: {num_params_g} learnable parameters')
print(f'Discrimintor has: {num_params_d} learnable parameters')
# Out:
# Generator has: 2413984 learnable parameters
# Discrimintor has: 1224351 learnable parameters

# %%
# Print settings
VERBOSE = True

# Plot settings
Z = torch.rand(size=(N_ROWS * N_COLS, DIM_NOISE), device=device) * 2 - 1
Y = torch.tensor([i for i in range(0, 10) for _ in range(0, 10)], device=device)
Y = F.one_hot(Y, num_classes=10).float()
PLOTTING = True
SAVE_LOC = './mnist_fake'

if PLOTTING:
    if not os.path.exists(SAVE_LOC):
        os.mkdir(SAVE_LOC)

# %% [markdown]
# #### Start Training

# %%
losses_d, losses_g = [], []
N_samples = len(dataset)
for epoch in range(EPOCHS):

    total_loss_g, total_loss_d = 0.0, 0.0
    for x, y in dataloader:
        # x is sampled from data generating distribution x ~ p_data
        x = x.to(device)
        y = F.one_hot(y.to(device), num_classes=10).float()

        # z is sampled from noise prior z ~ p_noise
        z = torch.rand(size=(x.shape[0], DIM_NOISE), device=device) * 2 - 1
        D_x = discriminator(x, y)
        D_G_z = discriminator(generator(z, y), y)

        # update descriminator by ascending its stochastic gradient
        optimizer_d.zero_grad()
        loss_d = criterion_d(D_x, D_G_z)
        loss_d.backward()
        optimizer_d.step()
        
        # z is sampled from noise prior
        # z ~ p_noise
        z = torch.rand(size=(x.shape[0], DIM_NOISE), device=device) * 2 - 1
        D_G_z = discriminator(generator(z, y), y)

        # update generator by descending its stochastic gradient
        optimizer_g.zero_grad()
        loss_g = criterion_g(D_G_z)
        loss_g.backward()
        optimizer_g.step()

        total_loss_d += loss_d.item() * x.shape[0]
        total_loss_g += loss_g.item() * z.shape[0]
    
    
    losses_d.append(total_loss_d / N_samples)
    losses_g.append(total_loss_g / N_samples)

    if VERBOSE: 
        print(
            f'epoch: {epoch}\t' 
            f'generator loss: {(total_loss_g/N_samples):.4f}\t'
            f'discriminator loss: {(total_loss_d/N_samples):.4f}'
        )

    if PLOTTING:
        G_z = generator(Z, Y)
        fig, ax = plt.subplots(nrows=N_ROWS, ncols=N_COLS, figsize=FIGSIZE)
        ax = ax.flatten()
        for i in range(N_ROWS * N_COLS):
            img = G_z[i].cpu().detach().numpy().reshape(IMAGE_SHAPE)
            ax[i].imshow(img, cmap='gray')
            ax[i].axis('off')
        fig.tight_layout()
        fig.savefig(os.path.join(SAVE_LOC, f'mnist_{epoch}'))
        plt.close(fig)
# Out:
# epoch: 0	generator loss: 3.8155	discriminator loss: 0.7067
# epoch: 1	generator loss: 4.6033	discriminator loss: 0.4181
# epoch: 2	generator loss: 2.7791	discriminator loss: 0.6661
# epoch: 3	generator loss: 1.8643	discriminator loss: 0.8928
# epoch: 4	generator loss: 1.4843	discriminator loss: 1.0264
# epoch: 5	generator loss: 1.3012	discriminator loss: 1.0964
# epoch: 6	generator loss: 1.1705	discriminator loss: 1.1601
# epoch: 7	generator loss: 1.0834	discriminator loss: 1.2059
# epoch: 8	generator loss: 1.0316	discriminator loss: 1.2320
# epoch: 9	generator loss: 0.9951	discriminator loss: 1.2551
# epoch: 10	generator loss: 0.9482	discriminator loss: 1.2840
# epoch: 11	generator loss: 0.9349	discriminator loss: 1.2965
# epoch: 12	generator loss: 0.9094	discriminator loss: 1.3131
# epoch: 13	generator loss: 0.9004	discriminator loss: 1.3190
# epoch: 14	generator loss: 0.8941	discriminator loss: 1.3243
# epoch: 15	generator loss: 0.8842	discriminator loss: 1.3312
# epoch: 16	generator loss: 0.8822	discriminator loss: 1.3339
# epoch: 17	generator loss: 0.8741	discriminator loss: 1.3371
# epoch: 18	generator loss: 0.8660	discriminator loss: 1.3451
# epoch: 19	generator loss: 0.8696	discriminator loss: 1.3414
# epoch: 20	generator loss: 0.8663	discriminator loss: 1.3443
# epoch: 21	generator loss: 0.8623	discriminator loss: 1.3466
# epoch: 22	generator loss: 0.8575	discriminator loss: 1.3514
# epoch: 23	generator loss: 0.8547	discriminator loss: 1.3530
# epoch: 24	generator loss: 0.8562	discriminator loss: 1.3532
# epoch: 25	generator loss: 0.8584	discriminator loss: 1.3521
# epoch: 26	generator loss: 0.8646	discriminator loss: 1.3482
# epoch: 27	generator loss: 0.8672	discriminator loss: 1.3471
# epoch: 28	generator loss: 0.8663	discriminator loss: 1.3497
# epoch: 29	generator loss: 0.8650	discriminator loss: 1.3500
# epoch: 30	generator loss: 0.8647	discriminator loss: 1.3514
# epoch: 31	generator loss: 0.8703	discriminator loss: 1.3477
# epoch: 32	generator loss: 0.8697	discriminator loss: 1.3515
# epoch: 33	generator loss: 0.8672	discriminator loss: 1.3508
# epoch: 34	generator loss: 0.8708	discriminator loss: 1.3478
# epoch: 35	generator loss: 0.8746	discriminator loss: 1.3483
# epoch: 36	generator loss: 0.8682	discriminator loss: 1.3519
# epoch: 37	generator loss: 0.8691	discriminator loss: 1.3486
# epoch: 38	generator loss: 0.8681	discriminator loss: 1.3513
# epoch: 39	generator loss: 0.8715	discriminator loss: 1.3492
# epoch: 40	generator loss: 0.8801	discriminator loss: 1.3454
# epoch: 41	generator loss: 0.8755	discriminator loss: 1.3499
# epoch: 42	generator loss: 0.8737	discriminator loss: 1.3495
# epoch: 43	generator loss: 0.8772	discriminator loss: 1.3479
# epoch: 44	generator loss: 0.8739	discriminator loss: 1.3528
# epoch: 45	generator loss: 0.8733	discriminator loss: 1.3518
# epoch: 46	generator loss: 0.8726	discriminator loss: 1.3512
# epoch: 47	generator loss: 0.8815	discriminator loss: 1.3493
# epoch: 48	generator loss: 0.8634	discriminator loss: 1.3547
# epoch: 49	generator loss: 0.8785	discriminator loss: 1.3495
# epoch: 50	generator loss: 0.8787	discriminator loss: 1.3503
# epoch: 51	generator loss: 0.8739	discriminator loss: 1.3480
# epoch: 52	generator loss: 0.8760	discriminator loss: 1.3497
# epoch: 53	generator loss: 0.8795	discriminator loss: 1.3500
# epoch: 54	generator loss: 0.8791	discriminator loss: 1.3481
# epoch: 55	generator loss: 0.8838	discriminator loss: 1.3494
# epoch: 56	generator loss: 0.8806	discriminator loss: 1.3497
# epoch: 57	generator loss: 0.8800	discriminator loss: 1.3491
# epoch: 58	generator loss: 0.8814	discriminator loss: 1.3492
# epoch: 59	generator loss: 0.8741	discriminator loss: 1.3513
# epoch: 60	generator loss: 0.8838	discriminator loss: 1.3483
# epoch: 61	generator loss: 0.8974	discriminator loss: 1.3453
# epoch: 62	generator loss: 0.8913	discriminator loss: 1.3441
# epoch: 63	generator loss: 0.8868	discriminator loss: 1.3462
# epoch: 64	generator loss: 0.8799	discriminator loss: 1.3488
# epoch: 65	generator loss: 0.8812	discriminator loss: 1.3496
# epoch: 66	generator loss: 0.8872	discriminator loss: 1.3432
# epoch: 67	generator loss: 0.8872	discriminator loss: 1.3471
# epoch: 68	generator loss: 0.8798	discriminator loss: 1.3487
# epoch: 69	generator loss: 0.8868	discriminator loss: 1.3444
# epoch: 70	generator loss: 0.8965	discriminator loss: 1.3444
# epoch: 71	generator loss: 0.9001	discriminator loss: 1.3413
# epoch: 72	generator loss: 0.8953	discriminator loss: 1.3407
# epoch: 73	generator loss: 0.9003	discriminator loss: 1.3368
# epoch: 74	generator loss: 0.8967	discriminator loss: 1.3411
# epoch: 75	generator loss: 0.8991	discriminator loss: 1.3374
# epoch: 76	generator loss: 0.9018	discriminator loss: 1.3396
# epoch: 77	generator loss: 0.8962	discriminator loss: 1.3413
# epoch: 78	generator loss: 0.9010	discriminator loss: 1.3400
# epoch: 79	generator loss: 0.9077	discriminator loss: 1.3386
# epoch: 80	generator loss: 0.9027	discriminator loss: 1.3388
# epoch: 81	generator loss: 0.9073	discriminator loss: 1.3403
# epoch: 82	generator loss: 0.9029	discriminator loss: 1.3402
# epoch: 83	generator loss: 0.8985	discriminator loss: 1.3392
# epoch: 84	generator loss: 0.9071	discriminator loss: 1.3360
# epoch: 85	generator loss: 0.9072	discriminator loss: 1.3347
# epoch: 86	generator loss: 0.9016	discriminator loss: 1.3409
# epoch: 87	generator loss: 0.9075	discriminator loss: 1.3368
# epoch: 88	generator loss: 0.9083	discriminator loss: 1.3354
# epoch: 89	generator loss: 0.9095	discriminator loss: 1.3342
# epoch: 90	generator loss: 0.9079	discriminator loss: 1.3320
# epoch: 91	generator loss: 0.9052	discriminator loss: 1.3356
# epoch: 92	generator loss: 0.9109	discriminator loss: 1.3317
# epoch: 93	generator loss: 0.9079	discriminator loss: 1.3347
# epoch: 94	generator loss: 0.9173	discriminator loss: 1.3292
# epoch: 95	generator loss: 0.9152	discriminator loss: 1.3304
# epoch: 96	generator loss: 0.9158	discriminator loss: 1.3272
# epoch: 97	generator loss: 0.9172	discriminator loss: 1.3299
# epoch: 98	generator loss: 0.9100	discriminator loss: 1.3336
# epoch: 99	generator loss: 0.9237	discriminator loss: 1.3290

# %% [markdown]
# #### GAN Training Losses

# %%
_, ax = plt.subplots()
ax.plot(np.arange(len(losses_g)), losses_g, label='Generator loss')
ax.plot(np.arange(len(losses_d)), losses_d, label='Discriminator loss')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### Generating Fake Data

# %%
Z = torch.rand(size=(N_ROWS * N_COLS, DIM_NOISE), device=device) * 2 - 1
Y = torch.tensor([i for i in range(0, 10) for _ in range(0, 10)], device=device)
Y = F.one_hot(Y, num_classes=10).float()
data_fake = generator(Z, Y)

_, ax = plt.subplots(nrows=N_ROWS, ncols=N_COLS, figsize=FIGSIZE)
ax = ax.flatten()
for i in range(N_ROWS * N_COLS):
    img = data_fake[i].cpu().detach().numpy().reshape(IMAGE_SHAPE)
    ax[i].imshow(img, cmap='gray')
    ax[i].set_xticks([]),
    ax[i].set_yticks([])
plt.tight_layout()
plt.show()
